# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from datatools.WRF.viz import Visualization2D

# %% [markdown]
# ## WRF solution processing

# %%
fname_format = 'wrfout_d02_%Y-%m-%d_%H_%M_%S'

# %%
# %time viz = Visualization2D(parse_datetime=fname_format)
# Out:
# CPU times: user 33.4 s, sys: 55.4 s, total: 1min 28s
# Wall time: 5.09 s

# %%
viz
# Out:
# 9 times read:
#   wrfout_d02_0001-01-01_05_00_00
#   wrfout_d02_0001-01-01_05_15_00
#   wrfout_d02_0001-01-01_05_30_00
#   ...
#   wrfout_d02_0001-01-01_06_45_00
#   wrfout_d02_0001-01-01_07_00_00
# Dimensions: (528, 528, 149)

# %%
viz.interactive()
# Out:
# interactive(children=(Dropdown(description='field', options=('U', 'V', 'W', 'T'), value='U'), Text(value='90.0…

# %%
#viz.plot_mean_profile()
viz.plot_mean_profiles_over_time('T')
# Out:
# mean over x:[    0. 47430.], y:[    0. 47430.]
#   area is 47430.0 by 47430.0 m^2
# averaging T over 9 times, could take a while...

# %%
viz.timeheight_mean_profiles('T')
# Out:
# mean over x:[    0. 47430.], y:[    0. 47430.]
#   area is 47430.0 by 47430.0 m^2
# averaging T over 9 times, could take a while...
